# %% [markdown]
# <a href="https://colab.research.google.com/github/sohaniyewale/sentimentanalysis_/blob/main/sentimenttimeseries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from transformers import pipeline


bearer_token = input("Enter your Twitter Bearer Token: ").strip()


client = tweepy.Client(bearer_token=bearer_token)


sentiment_pipeline = pipeline('sentiment-analysis', model='ProsusAI/finbert')


query = "stock market OR inflation OR economy"


tweets = client.search_recent_tweets(query=query,
                                     tweet_fields=['created_at', 'public_metrics', 'text', 'author_id'],
                                     user_fields=['username', 'verified'],
                                     expansions='author_id',
                                     max_results=10)

print("\nFetching and Analyzing Tweets...\n")
sentiment_scores = {"positive": 0, "negative": 0, "neutral": 0}
total_tweets = 0


if tweets.data and tweets.includes and 'users' in tweets.includes:
    user_dict = {user.id: user for user in tweets.includes['users']}

    for tweet in tweets.data:
        user = user_dict.get(tweet.author_id, None)
        sentiment = sentiment_pipeline(tweet.text)[0]

        print(f"Tweet: {tweet.text}")
        if user:
            print(f"Username: {user.username}")
            print(f"Verified: {'Yes' if user.verified else 'No'}")
        print(f"Created At: {tweet.created_at}")
        print(f"Likes: {tweet.public_metrics['like_count']}, Retweets: {tweet.public_metrics['retweet_count']}")
        print(f"Sentiment: {sentiment['label']}, Score: {sentiment['score']:.2f}")
        print("-" * 50)

        sentiment_label = sentiment['label'].lower()
        sentiment_scores[sentiment_label] += 1
        total_tweets += 1
else:
    print("No tweets found or user data missing.")


if total_tweets > 0:
    print("\nFinal Sentiment Report:")
    for sentiment, count in sentiment_scores.items():
        percentage = (count / total_tweets) * 100
        print(f"{sentiment.capitalize()}: {count} tweets ({percentage:.2f}%)")
else:
    print("No sentiment data to display.")
# Out:
# Enter your Twitter Bearer Token: AAAAAAAAAAAAAAAAAAAAAEYZ2AEAAAAAgZUak%2BpGjEIgXPLsJP5eQGblVNc%3D4hPGXlphUeFbK8SzKyaDxUO8bSG9xIIuMEG1x7z4TSg0x9qtjI
# Device set to use cpu
# Fetching and Analyzing Tweets...
#
# Tweet: @HarryPoker21 @MalditoKiwi @LANACION @MalditoKiwi @LANACION Under Cristina Kirchner (2007-2015), real wages likely grew, with the minimum wage tripling in real terms, though inflation sometimes eroded gains. Under Javier Milei (2023-2025), wages initially dropped sharply due to austerity and devaluation, with a
# Username: grok
# Verified: Yes
# Created At: 2025-05-26 16:09:42+00:00
# Likes: 0, Retweets: 0
# Sentiment: negative, Score: 0.94
# --------------------------------------------------
# Tweet: RT @DoctorHenryCT: 5 years ago Trump reopened the economy during Covid. We had over 100,000 dead and eventually 1M Americans died from Covi…
# Username: JimBonz
# Verified: No
# Created At: 2025-05-26 16:09:42+00:00
# Likes: 0, Retweets: 35
# Sentiment: neutral, Score: 0.84
# --------------------------------------------------
# Tweet: RT @rzkdhl: In this economy, living without privilege, usaha sampai berdarah-darah trus dikerjain kayak gini berkali-kali tuh ‘sialan’ bang…
# Username: fliptherose
# Verified: No
# Created At: 2025-05-26 16:09:42+00:00
# Likes: 0, Retweets: 556
# Sentiment: neutral, Score: 0.89
# --------------------------------------------------
# Tweet: 3. MAKE A MAN LOVE YOU FOR LIFE
# https://t.co/86ZWerZ8ha
# 4. HOW TO ATTRACT RICH MEN FOR RELATIONSHIP OR MARRIAGE
# https://t.co/cwochuvawC
# 5. CONNECTING WITH SUCCESSFUL PEOPLE
# https://t.co/KYhq9MqugG
# 6. DUTY ETHICS IN THE NEW ECONOMY
# https://t.co/jkO4N3Uv32
# Username: victorofvista
# Verified: No
# Created At: 2025-05-26 16:09:42+00:00
# Likes: 0, Retweets: 0
# Sentiment: neutral, Score: 0.91
# --------------------------------------------------
# Tweet: Risk taking and calculated bets are the keys to success, just like making a savvy trade in the stock market or landing a winning shot on the court
# Username: VictoriaWh98032
# Verified: No
# Created At: 2025-05-26 16:09:42+00:00
# Likes: 0, Retweets: 0
# Sentiment: neutral, Score: 0.90
# --------------------------------------------------
# Tweet: RT @dogeai_gov: @LeadingReport Bernie’s “progressive” agenda is a recipe for economic disaster. Expanding Medicare, hiking taxes, and price…
# Username: LlcNines
# Verified: No
# Created At: 2025-05-26 16:09:41+00:00
# Likes: 0, Retweets: 23
# Sentiment: negative, Score: 0.63
# --------------------------------------------------
# Tweet: RT @TARUNspeakss: Reality check:
#
# India's GDP Per capita income : $2,800
#
# Japan's PCI : $33,138
#
# And if you exclude Ambani &amp; Adani's wealth…
# Username: Risky59fps
# Verified: No
# Created At: 2025-05-26 16:09:41+00:00
# Likes: 0, Retweets: 1366
# Sentiment: neutral, Score: 0.93
# --------------------------------------------------
# Tweet: RT @Mayor_ofph: The HM of Finance and Coordinating Minister of the Economy (@FinMinNigeria), Mr. Wale Edun, today hosted a high-level deleg…
# Username: apro_dawildcat
# Verified: No
# Created At: 2025-05-26 16:09:41+00:00
# Likes: 0, Retweets: 5
# Sentiment: neutral, Score: 0.89
# --------------------------------------------------
# Tweet: RT @Sanju_Verma_: Suspended Idiot,read👇
#
# 📌Per Capita Household Wealth in India is $13400+
#
# 📌Jobs?We added 4.7Cr Jobs last yr
#
# 📌Debt?Central…
# Username: bhavnapb
# Verified: No
# Created At: 2025-05-26 16:09:41+00:00
# Likes: 0, Retweets: 118
# Sentiment: neutral, Score: 0.61
# --------------------------------------------------
# Tweet: RT @Ravisutanjani: 🚨 India is Now 4th Largest Economy
#
# Things That Every Citizen Should Do
#
# • Don’t Talk Loudly at Public Places
# • Use Earp…
# Username: sportsfan_0710
# Verified: No
# Created At: 2025-05-26 16:09:41+00:00
# Likes: 0, Retweets: 1368
# Sentiment: neutral, Score: 0.93
# --------------------------------------------------
#
# Final Sentiment Report:
# Positive: 0 tweets (0.00%)
# Negative: 2 tweets (20.00%)
# Neutral: 8 tweets (80.00%)

# %%
import tweepy
from transformers import pipeline
import csv
from datetime import datetime

def get_bearer_token():
    return input("Enter your Twitter Bearer Token: ").strip()

def get_search_query():
    return input("Enter your search query (e.g., stock market OR inflation): ").strip()

def initialize_twitter_client(bearer_token):
    return tweepy.Client(bearer_token=bearer_token)

def fetch_tweets(client, query, max_results=10):
    return client.search_recent_tweets(
        query=query,
        tweet_fields=['created_at', 'public_metrics', 'text', 'author_id'],
        user_fields=['username', 'verified'],
        expansions='author_id',
        max_results=max_results
    )

def analyze_sentiment(tweet_text, sentiment_pipeline):
    result = sentiment_pipeline(tweet_text)[0]
    return result['label'], result['score']

def save_to_csv(data, filename="tweet_sentiment_results.csv"):
    headers = ["Username", "Verified", "Created At", "Tweet", "Likes", "Retweets", "Sentiment", "Score"]
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(headers)
        writer.writerows(data)

def main():
    bearer_token = get_bearer_token()
    query = get_search_query()
    client = initialize_twitter_client(bearer_token)
    sentiment_pipeline = pipeline('sentiment-analysis', model='ProsusAI/finbert')
    tweets = fetch_tweets(client, query)

    sentiment_summary = {"positive": 0, "negative": 0, "neutral": 0}
    total_tweets = 0
    csv_data = []

    if tweets.data and tweets.includes and 'users' in tweets.includes:
        user_dict = {user.id: user for user in tweets.includes['users']}

        print("\nFetching and Analyzing Tweets...\n")

        for tweet in tweets.data:
            user = user_dict.get(tweet.author_id)
            sentiment_label, sentiment_score = analyze_sentiment(tweet.text, sentiment_pipeline)

            username = user.username if user else "Unknown"
            verified = "Yes" if user and user.verified else "No"
            created_at = tweet.created_at.strftime("%Y-%m-%d %H:%M:%S")
            likes = tweet.public_metrics['like_count']
            retweets = tweet.public_metrics['retweet_count']

            print(f"Tweet: {tweet.text}")
            print(f"Username: {username} | Verified: {verified}")
            print(f"Created At: {created_at}")
            print(f"Likes: {likes} | Retweets: {retweets}")
            print(f"Sentiment: {sentiment_label} | Score: {sentiment_score:.2f}")
            print("-" * 60)

            sentiment_summary[sentiment_label.lower()] += 1
            total_tweets += 1

            csv_data.append([username, verified, created_at, tweet.text, likes, retweets, sentiment_label, f"{sentiment_score:.2f}"])

    if total_tweets > 0:
        print("\nFinal Sentiment Summary:")
        for label, count in sentiment_summary.items():
            print(f"{label.capitalize()}: {count} ({(count/total_tweets)*100:.2f}%)")
        save_to_csv(csv_data)
    else:
        print("No tweets found or sentiment data to display.")

if __name__ == "__main__":
    main()
# Out:
# Enter your Twitter Bearer Token: AAAAAAAAAAAAAAAAAAAAAGQi0QEAAAAAoh05BSDF8AlBOKZ9NfUKMBipOfA%3Dufhw6nJ40lMQuD4JImbXamJg0A6uv44TF2v4TMeuauDvh8QW75
# Enter your search query (e.g., stock market OR inflation): inflation
# Device set to use cpu
# Fetching and Analyzing Tweets...
#
# Tweet: 🚀 Currently working on a paper on War Time Economics—a deep dive into how wars, past &amp; present, reshape economies and drive shifts toward specialized military production. It’s an ongoing project, updates will follow here. #WarEconomy #inflation
# Username: MayankKumar0299 | Verified: No
# Created At: 2025-05-26 16:13:32
# Likes: 0 | Retweets: 0
# Sentiment: neutral | Score: 0.92
# ------------------------------------------------------------
# Tweet: Your financial future is like a chess game - you need to make strategic moves to outmaneuver inflation and emerge victorious
# Username: DawsonamanDan | Verified: No
# Created At: 2025-05-26 16:13:32
# Likes: 0 | Retweets: 0
# Sentiment: neutral | Score: 0.90
# ------------------------------------------------------------
# Tweet: @BinStarterio Given the competitive nature of GameFi projects in 2025, what specific strategies is Akarun implementing to ensure $AKA’s tokenomics remain sustainable, particularly in balancing staking rewards (as asked by @Ziko_38
#  and @clownofama
# ) with preventing inflation, while also
# Username: AlphaBTC01 | Verified: No
# Created At: 2025-05-26 16:13:30
# Likes: 0 | Retweets: 0
# Sentiment: positive | Score: 0.80
# ------------------------------------------------------------
# Tweet: RT @DesmondBredu: The Monetary Policy Committe (MPC) of the Bank of Ghana has decided to maintain the policy rate at 28%.
#
# Here is what it…
# Username: bgs_santi | Verified: No
# Created At: 2025-05-26 16:13:30
# Likes: 0 | Retweets: 80
# Sentiment: neutral | Score: 0.93
# ------------------------------------------------------------
# Tweet: Riding the wave of inflation, savvy investors are turning to a lesser-known asset: rare collectible NFTs stored on a private ledger
# Username: AmyWilsonu_ | Verified: No
# Created At: 2025-05-26 16:13:29
# Likes: 0 | Retweets: 0
# Sentiment: neutral | Score: 0.90
# ------------------------------------------------------------
# Tweet: RT @Sanju_Verma_: Suspended Idiot,read👇
#
# 📌Per Capita Household Wealth in India is $13400+
#
# 📌Jobs?We added 4.7Cr Jobs last yr
#
# 📌Debt?Central…
# Username: Equity1988 | Verified: No
# Created At: 2025-05-26 16:13:29
# Likes: 0 | Retweets: 120
# Sentiment: neutral | Score: 0.61
# ------------------------------------------------------------
# Tweet: @protectorhektor @MindMatterMoney @1DollarSol $1 💎 ready to take off, look at us, join us soon #1dollar
# Just buy $1 worth of this coin
# for freedom of speech against inflation 📈. @1DollarSol
# This ⬇️⬇️⬇️
# GHichsGq8aPnqJyz6Jp1ASTK4PNLpB5KrD6XrfDjpump
# Username: HRoushani59717 | Verified: No
# Created At: 2025-05-26 16:13:24
# Likes: 0 | Retweets: 0
# Sentiment: neutral | Score: 0.85
# ------------------------------------------------------------
# Tweet: @RepShontelBrown You must not have heard the "numerous public officials" who said: there was no inflation
# the border was secure
# Joe Biden isn't a vegetable
#
# Nobody give a shit about your pathetic lies anymore.
#
# GFY
# Username: Euphornicate | Verified: No
# Created At: 2025-05-26 16:13:24
# Likes: 0 | Retweets: 0
# Sentiment: neutral | Score: 0.79
# ------------------------------------------------------------
# Tweet: RT @CobakOfficial: Nearly 10M Koreans now use crypto — 1 in 5 citizens.
# It’s no longer a trend but a signal: old beliefs like “save and you…
# Username: gler_song | Verified: No
# Created At: 2025-05-26 16:13:22
# Likes: 0 | Retweets: 850
# Sentiment: neutral | Score: 0.92
# ------------------------------------------------------------
# Tweet: @SisyphusAnon @VladTheInflator It’s more like 20-30% is the real inflation
# Username: Epark22 | Verified: No
# Created At: 2025-05-26 16:13:21
# Likes: 0 | Retweets: 0
# Sentiment: neutral | Score: 0.93
# ------------------------------------------------------------
#
# Final Sentiment Summary:
# Positive: 1 (10.00%)
# Negative: 0 (0.00%)
# Neutral: 9 (90.00%)
